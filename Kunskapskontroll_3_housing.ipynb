# %% [markdown]
# ABSTRACT
# Exploratory Data Analysis EDA
#
# The Task:
# Execute visualisation, calculation and processing on the housing dataset in order to identify issues prior to modelling
#
# The Goal:
# It shall be possible to follow the analysis, from scriptresult to a conclusion:
# That is, suggesting futher actions on a selected group of issues to handle in the file housing.csv.
#
# The result:
# I selected the following issues interresting enough to be discussed.
#
# Issue 1:
# Horizontal bars indicating an upper limit for certain variables.
# Why: This could be deliberate to avoid unrepresentative values.
# It could also depend on a computational error.
#
# Issue 2:
# An almost perfect linear relationship between two variables.
# Why: A coincidense or a duplicate error.
#
# Issue 3:
# Each dot in the california map represent a district. Not a building.This creates misleading results when using the other variables.
#
# Issue 4:
# The data is produced during the 90´s. I visited Caifornia 1992 and therefore i know how troublesome it is to use districts instead of buildings as californian housing is somewhat unique.
#
# Issue 5:
# There are five different district areas in the variable ocean_proximity. One of them, "ISLAND", has very few districts and thus very few observations. It therefore risks making the calculation more complex and also risks misguiding paths to proper suggestions.

# %% [markdown]
# Exploratory Data Analysis (EDA) -
#
# Define the problem, together with the stakeholders, find the "pain", purpose of data analysis, and goal.
# Decide datasources to use, where to store data, data training governance and scope. Also if any development via scripts/API is necessary.
# Process the data. Wash, refine, remove bias or spurious to prevent outcome disruption.
# Finally, ML modelling and production of dashboard.

# %% [markdown]
# USE CASE EDA
#
# A Real estate broker in California is interrested in a
# housing data analysis to improve customer satisfaction.
# The overall question for this EDA is according to Stakeholder:
# - What features do people look for when buying a new house?
#
# By using SMART questions the data analyst can clarify the stakeholder needs and data prior to the exploratory data analysis (EDA).
# The data analyst use SMART questions(below) concerning the available housing.csv spreadsheet
#
# Specific: Does the data focus on a particular housing feature?
#     Answer:
#     No, interview necessary with stakeholders additional data
#
# Measurable: Does the data include a housing feature rating system?
#     Answer:
#     Partly, but far from complete
#
# Action-oriented: Does the data influence creation of different or new feature packages within house sales?
#     Answer:
#     Yes
#
# Relevant: Does the data identify which features make or break a potential house purchase?
#     Answer:
#     No
#
# Time-bound: Does the data validate the most popular features from the last three years?
#     Answer:
#     No, further questions needed.

# %% [markdown]
# Exploratory data analysis

# %% [markdown]
# Which houses are cheap or expensive and why
# Which datasets are missing
# Which datasets are redundant
# Process the data. Wash, refine, remove bias or spurious to prevent outcome disruption.
#
# Exploratory Data Analysis EDA
# execute
# visualisation
# Calculation
# Processing
#
# on the housing dataset in order to identify
# Missing datapoints
# Missing datasets
#
# The goal is to follow the analysis by reading the script and your conclusion
# For example
# Which houses ar cheaper or more expensive, and why?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
housing = pd.read_csv("housing.csv")
housing.plot(x='median_income', y='median_house_value', kind='scatter', alpha=0.3, title='Upper limit 500000')
housing.plot(x='total_rooms', y='median_income', kind='scatter', alpha=0.3, title='Upper limit 15')
plt.show()

# %% [markdown]
# ABOVE
#
# An interresting observation is the horisontal bar that appears on the y-axis position 500000 on the first figure
# and on y-axis position 15 on the second figure.
#
# Why are there horizontal bars ?
#
# This could be deliberate to avoid unrepresentative values.
# It could also depend on an input error.
# The Data Analyst must therefore consider discussing this data with the stakeholder, to commit a responsible solution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
housing = pd.read_csv("housing.csv")
attributes=["total_bedrooms", "households"]
#attributes=["housing_median_age", "median_house_value", "median_income", "total_rooms", "total_bedrooms", "households", "population"]
#"longitude", "latitude", longitude	latitude	housing_median_age	total_rooms	total_bedrooms	population	households	median_income	median_house_value	ocean_proximity
pd.plotting.scatter_matrix(housing[attributes], figsize=(5,5))
plt.show()

# %% [markdown]
# ABOVE
# Notice the perfect linear relationship between the variables
# "households" and "total_bedrooms".
# The variables plots an almost perfect linear correlationcoefficient of +1
#
# This calls for action
# The Data analyst must consider removing one of the variables
# "households" or "total_bedrooms".
# Two equal variables will not add value, only make the analysis more complex.It is also possible that one of the variables show incorrect data. Perhaps due to a duplicate error of values or variable name.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# 1. Läs in bilden
map_img = mpimg.imread('california.png')

# 2. Definiera bildens koordinatgränser (Exempelvärden, byt ut mot dina!)
# Format: [min_lon, max_lon, min_lat, max_lat]
img_extent = [-124.55, -113.80, 32.45, 42.05]

# 3. Skapa plotten
fig, ax = plt.subplots(figsize=(10, 8))

# Lägg in kartan som bakgrund
ax.imshow(map_img, extent=img_extent, alpha=0.5)

# 4. Plotta din dataframe ovanpå
# Se till att x är longitud och y är latitud
df.plot(kind='scatter', x='longitude', y='latitude', 
        ax=ax,                 # Mycket viktigt: plotta i samma axel
        c='median_house_value', # Exempel på färgstyrning
        cmap='Wistia', vmin= 1, vmax=1000000, 
        alpha=0.8)

plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.show()

# %% [markdown]
# ABOVE
#
# This is the map over California
#
# the Longitude(X-axis horizontal) and Latitude(Y-axis vertical) coordinates represents the WGS 84 standard used in GPS.
# By creating a scatter of this GPS data aligned with the map image, a lot of coloured dots appears. Each dot on the map represent a "district" of California during the 90´s. The dots colour reveals the varying "median house value" of each district. (Green has lowest median value and Orange the highest)
#
#  There are some issues to watch out for with this data. Actual buildings, size and prices are not present in the dataset. As a data analyst the following must be taken into consideration when performing the EDA:
#
# Old data:
#     Old data does not show todays house prices, nor how the architectural landscape has evolved. The housing.csv data was gathered some 30 years ago. It could give an indication but cannot be used professionally by a real estate broker.
#
# Value statistics per district:
#     The median house value of a district doesnt necessary represent the normal distribution of bouldings . as buildings in california varies from, manisons, hotels, skyscrapers, Entertainment parks, villas, residential areas, schools and trailor parks. And some district varies from a few citizens up to half a million.
#
# Bias:
# there is a lot of different buildings. Some buildings may not be representative and should therefore be excluded.
#
#
# As a data analyst it is necessary to discuss all of the above with the stakeholders to eliminate misinterpretations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# longitude	latitude	housing_median_age	total_rooms	total_bedrooms	population	households	median_income	median_house_value	ocean_proximity
df = pd.read_csv("housing.csv")
# Skapar en figur med x rader och y kolumner 
fig, axes = plt.subplots(nrows=7, ncols=1, figsize=(20, 30))
# Platta till arrayen för att enklare iterera eller komma åt dem (axes[0], axes[1]...)
ax = axes.flatten()
df.plot(x='ocean_proximity', y='housing_median_age', alpha=0.1, ax=ax[0], kind='scatter', title='Plot 1 housing_median_age')
df.plot(x='total_rooms', y='ocean_proximity', alpha=0.1, ax=ax[1], kind='scatter', title='Plot 2 total_rooms')
df.plot(x='total_bedrooms', y='ocean_proximity', alpha=0.1, ax=ax[2], kind='scatter', title='Plot 3 total_bedrooms')
df.plot(x='population', y='ocean_proximity', alpha=0.1, ax=ax[3], kind='scatter', title='Plot 4 population')
df.plot(x='households', y='ocean_proximity', alpha=0.1, ax=ax[4], kind='scatter', title='Plot 5 households')
df.plot(x='median_income', y='ocean_proximity', alpha=0.1, ax=ax[5], kind='scatter', title='Plot 6 median_income')
df.plot(x='median_house_value', y='ocean_proximity', alpha=0.1, ax=ax[6], kind='scatter', title='Plot 7 median_house_value')

#housing.plot(x='population', y='ocean_proximity', kind='scatter')
# Justera layouten så att titlar och etiketter inte krockar
plt.tight_layout()
plt.show()

# %% [markdown]
# ABOVE
# Seven plofigures above shows the variable ocean_proximity - the only variable with datatype "string", plotted against all other relevant "float" variables from the housing.csv dataset.
#
# There are five different district areas in the variable ocean_proximity:
#     ISLAND
#     NEAR OCEAN
#     INLAND
#     <1H OCEAN
#     NEAR BAY
#
# Looking at the seven plotted figures above proofs that ISLAND has very few districts and thus very few observations.
#
# A data analyst should therefore consider removing the district area ISLAND as it risks making the calculation more complex and also risks misguiding paths to proper suggestions.

# %% [markdown]
# SJÄLVUTVÄRDERING
#
# I slutet av koden ska du genomföra en självutvärdering där du besvarar följande tre frågor:
#
# 1. Har något varit utmanande i kursen/kunskapskontrollerna? Om ja, hur har du hanterat det? Vissa kunskapskontroller tog längre tid att lösa än jag beräknat. Men nu har jag anpassat mig och tagit kontroll på det.
#
# Vilka lärdomar tar du med dig till framtida kurser?
# Time management är viktigast. Det tar tid och man behöver planera sin tid mycket mer.
#
# 2. Vilket betyg anser du att du ska ha och varför? Jag arbetar för att få högsta betyg då det är viktigt för mig som jobbsökande att komma in på AI arbetsmarknaden. AI är intressant för att det ger mig möjlighet att förverkliga mina drömmar och ideer jag tidigare bara kunnat arbeta med i teorin exempelvis inom IT managementsystem.
#
# 3. Något du vill lyfta fram till Terese? Keep up the good work. Bra att kursen hålls verklighetsnära. AI Laborationerna verkar väldigt intressanta. Jag är mycket intresserad av ansiktsigenkänning och liknande AI relaterat arbete, vilket också lyfts fram. Exempelvis sifferigenkänning som eventuell lab, vilket verkar kul. Jag är motiverad!
#
# MYCKET BRA KURS!
